# %%
dataset.describe()
# Out:
#              FL_NUM         MONTH  DAY_OF_MONTH   DAY_OF_WEEK  CRS_ARR_TIME  \
# count  11231.000000  11231.000000  11231.000000  11231.000000  11231.000000
# mean    1334.325617      6.628973     15.790758      3.960199   1537.312795
# std      811.875227      3.354678      8.782056      1.995257    502.512494
# min        7.000000      1.000000      1.000000      1.000000      2.000000
# 25%      624.000000      4.000000      8.000000      2.000000   1130.000000
# 50%     1267.000000      7.000000     16.000000      4.000000   1559.000000
# 75%     2032.000000      9.000000     23.000000      6.000000   1952.000000
# max     2853.000000     12.000000     31.000000      7.000000   2359.000000
#
#           DEP_DEL15     ARR_DEL15  CRS_ARS_TIME      ORIGIN_0      ORIGIN_1  \
# count  11231.000000  11231.000000  11231.000000  11231.000000  11231.000000
# mean       0.141483      0.139168     15.067314      0.276022      0.195975
# std        0.348535      0.346138      5.023534      0.447048      0.396967
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000     11.000000      0.000000      0.000000
# 50%        0.000000      0.000000     15.000000      0.000000      0.000000
# 75%        0.000000      0.000000     19.000000      1.000000      0.000000
# max        1.000000      1.000000     23.000000      1.000000      1.000000
#
#            ORIGIN_2      ORIGIN_3      ORIGIN_4        DEST_0        DEST_1  \
# count  11231.000000  11231.000000  11231.000000  11231.000000  11231.000000
# mean       0.122340      0.225982      0.179681      0.286795      0.196866
# std        0.327693      0.418246      0.383939      0.452285      0.397648
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      1.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#              DEST_2        DEST_3        DEST_4
# count  11231.000000  11231.000000  11231.000000
# mean       0.116820      0.221975      0.177544
# std        0.321219      0.415593      0.382146
# min        0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000

# %%
sns.distplot(dataset.MONTH)
# Out:
# <ipython-input-50-43f5c122a6ef>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset.MONTH)
# <Axes: xlabel='MONTH', ylabel='Density'>

# %%
sns.scatterplot(x='DEP_DEL15',y='ARR_DEL15',data=dataset)
# Out:
# <Axes: xlabel='DEP_DEL15', ylabel='ARR_DEL15'>

# %%
sns.catplot(x="ARR_DEL15",y="DEP_DEL15",kind='bar',data=dataset)

# %%
sns.heatmap(dataset.corr())
# Out:
# <Axes: >

# %%
dataset = pd.get_dummies(dataset, columns=["ORIGIN","DEST"])
dataset.head()
x = dataset.iloc[:, 0:8].values
y = dataset.iloc[:, 8:9].values

# %%
x_train.shape
# Out:
# (8984, 6)

# %%
x_test.shape
# Out:
# (2247, 6)

# %%
y_test.shape
# Out:
# (2247, 1)

# %%
y_train.shape
# Out:
# (8984, 1)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=0)
